# %%
import pandas as pd

# %%
# Read data

# %%
df = pd.read_csv('data/full_game_rotation_data_of_playoffs_for_past_5_years.csv')
df.IN_TIME_REAL = df.IN_TIME_REAL / 10.0
df.OUT_TIME_REAL = df.OUT_TIME_REAL / 10.0
df.MIN = df.MIN / 10.0

# %%
# Find starting 5

# %%
df['STARTING_5'] = df.groupby(['GAME_ID', 'PERSON_ID'])['IN_TIME_REAL'].transform('min') == 0

# %%
# Find total playtime per game and player

# %%
df['DURATION'] = df.OUT_TIME_REAL - df.IN_TIME_REAL
df['PLAYTIME_PP_PG'] = df.groupby(['GAME_ID', 'PERSON_ID'])['DURATION'].transform('sum')

# %%
# Find avg player playtime per game per team

# %%
df['AVG_PLAYER_PLAYTIME_PG_PT'] = df[['GAME_ID', 'TEAM_ID', 'PERSON_ID', 'PLAYTIME_PP_PG']].drop_duplicates()\
                                    .groupby(['GAME_ID', 'TEAM_ID'])['PLAYTIME_PP_PG'].transform('mean')

# %%
# Find avg player playtime per game per team of starting 5

# %%
df['AVG_PLAYER_PLAYTIME_PG_PT_S5'] = df[df.STARTING_5][['GAME_ID', 'TEAM_ID', 'PERSON_ID', 'PLAYTIME_PP_PG']]\
                                    .drop_duplicates()\
                                    .groupby(['GAME_ID', 'TEAM_ID'])['PLAYTIME_PP_PG'].transform('mean')

# %%
# Find avg continuous player playtime per game per team

# %%
df['AVG_CNT_PLAYER_PLAYTIME_PG_PT'] = df.groupby(['GAME_ID', 'TEAM_ID'])['DURATION'].transform('mean')

# %%
# Find avg continuous player playtime per game per team of starting 5

# %%
df['AVG_CNT_PLAYER_PLAYTIME_PG_PT_S5'] = df[df.STARTING_5].groupby(['GAME_ID', 'TEAM_ID'])['DURATION']\
                                                       .transform('mean')

# %%
df.head(30)
# Out:
#     Unnamed: 0   GAME_ID     TEAM_ID    TEAM_CITY TEAM_NAME  PERSON_ID  \
# 0            0  41900406  1610612747  L.A. Lakers    Lakers       2544
# 1            1  41900406  1610612747  L.A. Lakers    Lakers       2544
# 2            2  41900406  1610612747  L.A. Lakers    Lakers       2544
# 3            3  41900406  1610612747  L.A. Lakers    Lakers       2544
# 4            4  41900406  1610612747  L.A. Lakers    Lakers       2730
# 5            5  41900406  1610612747  L.A. Lakers    Lakers     200765
# 6            6  41900406  1610612747  L.A. Lakers    Lakers     200765
# 7            7  41900406  1610612747  L.A. Lakers    Lakers     200765
# 8            8  41900406  1610612747  L.A. Lakers    Lakers     200765
# 9            9  41900406  1610612747  L.A. Lakers    Lakers     201162
# 10          10  41900406  1610612747  L.A. Lakers    Lakers     201980
# 11          11  41900406  1610612747  L.A. Lakers    Lakers     201980
# 12          12  41900406  1610612747  L.A. Lakers    Lakers     201980
# 13          13  41900406  1610612747  L.A. Lakers    Lakers     201980
# 14          14  41900406  1610612747  L.A. Lakers    Lakers     202693
# 15          15  41900406  1610612747  L.A. Lakers    Lakers     202693
# 16          16  41900406  1610612747  L.A. Lakers    Lakers     203076
# 17          17  41900406  1610612747  L.A. Lakers    Lakers     203076
# 18          18  41900406  1610612747  L.A. Lakers    Lakers     203076
# 19          19  41900406  1610612747  L.A. Lakers    Lakers     203484
# 20          20  41900406  1610612747  L.A. Lakers    Lakers     203484
# 21          21  41900406  1610612747  L.A. Lakers    Lakers     203484
# 22          22  41900406  1610612747  L.A. Lakers    Lakers    1626188
# 23          23  41900406  1610612747  L.A. Lakers    Lakers    1627936
# 24          24  41900406  1610612747  L.A. Lakers    Lakers    1627936
# 25          25  41900406  1610612747  L.A. Lakers    Lakers    1627936
# 26          26  41900406  1610612747  L.A. Lakers    Lakers    1627936
# 27          27  41900406  1610612747  L.A. Lakers    Lakers    1627936
# 28          28  41900406  1610612747  L.A. Lakers    Lakers    1627936
# 29          29  41900406  1610612747  L.A. Lakers    Lakers    1627936
#
#    PLAYER_FIRST    PLAYER_LAST  IN_TIME_REAL  OUT_TIME_REAL  ...  WL   MIN  \
# 0        LeBron          James           0.0          488.0  ...   W  23.9
# 1        LeBron          James         583.0         1012.0  ...   W  23.9
# 2        LeBron          James        1155.0         1728.0  ...   W  23.9
# 3        LeBron          James        1810.0         2793.0  ...   W  23.9
# 4        Dwight         Howard        2814.0         2880.0  ...   W  23.9
# 5         Rajon          Rondo         399.0          829.0  ...   W  23.9
# 6         Rajon          Rondo        1012.0         1440.0  ...   W  23.9
# 7         Rajon          Rondo        1728.0         2305.0  ...   W  23.9
# 8         Rajon          Rondo        2424.0         2814.0  ...   W  23.9
# 9         Jared         Dudley        2793.0         2880.0  ...   W  23.9
# 10        Danny          Green           0.0          399.0  ...   W  23.9
# 11        Danny          Green         720.0         1161.0  ...   W  23.9
# 12        Danny          Green        1440.0         1810.0  ...   W  23.9
# 13        Danny          Green        2160.0         2424.0  ...   W  23.9
# 14     Markieff         Morris         488.0         1155.0  ...   W  23.9
# 15     Markieff         Morris        1910.0         2241.0  ...   W  23.9
# 16      Anthony          Davis           0.0          656.0  ...   W  23.9
# 17      Anthony          Davis        1012.0         1910.0  ...   W  23.9
# 18      Anthony          Davis        2241.0         2793.0  ...   W  23.9
# 19   Kentavious  Caldwell-Pope           0.0          583.0  ...   W  23.9
# 20   Kentavious  Caldwell-Pope        1063.0         2030.0  ...   W  23.9
# 21   Kentavious  Caldwell-Pope        2424.0         2880.0  ...   W  23.9
# 22        Quinn           Cook        2793.0         2880.0  ...   W  23.9
# 23         Alex         Caruso           0.0          488.0  ...   W  23.9
# 24         Alex         Caruso         656.0          720.0  ...   W  23.9
# 25         Alex         Caruso         829.0         1063.0  ...   W  23.9
# 26         Alex         Caruso        1161.0         1810.0  ...   W  23.9
# 27         Alex         Caruso        2030.0         2160.0  ...   W  23.9
# 28         Alex         Caruso        2305.0         2424.0  ...   W  23.9
# 29         Alex         Caruso        2602.0         2880.0  ...   W  23.9
#
#     PTS  STARTING_5  DURATION PLAYTIME_PP_PG AVG_PLAYER_PLAYTIME_PG_PT  \
# 0   106        True     488.0         2473.0               1309.090909
# 1   106        True     429.0         2473.0                       NaN
# 2   106        True     573.0         2473.0                       NaN
# 3   106        True     983.0         2473.0                       NaN
# 4   106       False      66.0           66.0               1309.090909
# 5   106       False     430.0         1825.0               1309.090909
# 6   106       False     428.0         1825.0                       NaN
# 7   106       False     577.0         1825.0                       NaN
# 8   106       False     390.0         1825.0                       NaN
# 9   106       False      87.0           87.0               1309.090909
# 10  106        True     399.0         1474.0               1309.090909
# 11  106        True     441.0         1474.0                       NaN
# 12  106        True     370.0         1474.0                       NaN
# 13  106        True     264.0         1474.0                       NaN
# 14  106       False     667.0          998.0               1309.090909
# 15  106       False     331.0          998.0                       NaN
# 16  106        True     656.0         2106.0               1309.090909
# 17  106        True     898.0         2106.0                       NaN
# 18  106        True     552.0         2106.0                       NaN
# 19  106        True     583.0         2006.0               1309.090909
# 20  106        True     967.0         2006.0                       NaN
# 21  106        True     456.0         2006.0                       NaN
# 22  106       False      87.0           87.0               1309.090909
# 23  106        True     488.0         1962.0               1309.090909
# 24  106        True      64.0         1962.0                       NaN
# 25  106        True     234.0         1962.0                       NaN
# 26  106        True     649.0         1962.0                       NaN
# 27  106        True     130.0         1962.0                       NaN
# 28  106        True     119.0         1962.0                       NaN
# 29  106        True     278.0         1962.0                       NaN
#
#    AVG_PLAYER_PLAYTIME_PG_PT_S5 AVG_CNT_PLAYER_PLAYTIME_PG_PT  \
# 0                        2004.2                         450.0
# 1                           NaN                         450.0
# 2                           NaN                         450.0
# 3                           NaN                         450.0
# 4                           NaN                         450.0
# 5                           NaN                         450.0
# 6                           NaN                         450.0
# 7                           NaN                         450.0
# 8                           NaN                         450.0
# 9                           NaN                         450.0
# 10                       2004.2                         450.0
# 11                          NaN                         450.0
# 12                          NaN                         450.0
# 13                          NaN                         450.0
# 14                          NaN                         450.0
# 15                          NaN                         450.0
# 16                       2004.2                         450.0
# 17                          NaN                         450.0
# 18                          NaN                         450.0
# 19                       2004.2                         450.0
# 20                          NaN                         450.0
# 21                          NaN                         450.0
# 22                          NaN                         450.0
# 23                       2004.2                         450.0
# 24                          NaN                         450.0
# 25                          NaN                         450.0
# 26                          NaN                         450.0
# 27                          NaN                         450.0
# 28                          NaN                         450.0
# 29                          NaN                         450.0
#
#     AVG_CNT_PLAYER_PLAYTIME_PG_PT_S5
# 0                         477.190476
# 1                         477.190476
# 2                         477.190476
# 3                         477.190476
# 4                                NaN
# 5                                NaN
# 6                                NaN
# 7                                NaN
# 8                                NaN
# 9                                NaN
# 10                        477.190476
# 11                        477.190476
# 12                        477.190476
# 13                        477.190476
# 14                               NaN
# 15                               NaN
# 16                        477.190476
# 17                        477.190476
# 18                        477.190476
# 19                        477.190476
# 20                        477.190476
# 21                        477.190476
# 22                               NaN
# 23                        477.190476
# 24                        477.190476
# 25                        477.190476
# 26                        477.190476
# 27                        477.190476
# 28                        477.190476
# 29                        477.190476
#
# [30 rows x 28 columns]
